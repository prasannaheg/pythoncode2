# %%
import pandas as pd
df=pd.read_csv("D:\AI ML b1\weather.csv b1.csv")
df
# Out:
#        Data.Precipitation Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  1/3/2016           1             3       2016
# 1                    0.00  1/3/2016           1             3       2016
# 2                    0.16  1/3/2016           1             3       2016
# 3                    0.00  1/3/2016           1             3       2016
# 4                    0.01  1/3/2016           1             3       2016
# ...                   ...       ...         ...           ...        ...
# 16738                0.08  1/1/2017           1             1       2017
# 16739                0.00  1/1/2017           1             1       2017
# 16740                0.00  1/1/2017           1             1       2017
# 16741                0.06  1/1/2017           1             1       2017
# 16742                0.10  1/1/2017           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.pivot(index="Date.Full",columns="Station.City")
# Out:
#              Data.Precipitation                                             \
# Station.City          Anchorage Annette Bethel Bettles Birmingham Cold Bay
# Date.Full
# 1/3/2016                   0.01    0.09   0.05    0.15        0.0      0.6
#
#                                                                  ...  \
# Station.City Cordova Delta Junction/Ft Greely Fairbanks Gulkana  ...
# Date.Full                                                        ...
# 1/3/2016        2.15                      0.0       0.0    0.02  ...
#
#              Data.Wind.Speed                                                   \
# Station.City         Gulkana  Homer Huntsville Iliamna Juneau Kenai Ketchikan
# Date.Full
# 1/3/2016                8.23  11.26       3.86   19.76   9.23  11.2      6.16
#
#
# Station.City King Salmon Mobile Montgomery
# Date.Full
# 1/3/2016           18.83   9.73       6.86
#
# [1 rows x 228 columns]
