# %%
import pandas as pd
df=pd.DataFrame(data={
    'day':['mon','tue','wed','thu','fri'],
    'google':[1129,1132,1134,1152,1152],
    'apple':[191,192,190,190,188],
    'sumsung':[191,192,190,190,188]
})
df
# Out:
#    day  google  apple  sumsung
# 0  mon    1129    191      191
# 1  tue    1132    192      192
# 2  wed    1134    190      190
# 3  thu    1152    190      190
# 4  fri    1152    188      188

# %%
reshape_df=df.melt(id_vars=['day'])
reshape_df
# Out:
#     day variable  value
# 0   man   google   1129
# 1   tue   google   1132
# 2   wed   google   1134
# 3   thu   google   1152
# 4   fri   google   1152
# 5   man    apple    191
# 6   tue    apple    192
# 7   wed    apple    190
# 8   thu    apple    190
# 9   fri    apple    188
# 10  man  sumsung    191
# 11  tue  sumsung    192
# 12  wed  sumsung    190
# 13  thu  sumsung    190
# 14  fri  sumsung    188

# %%
reshape_df.columns=[['day','company','closing price']]
reshape_df
# Out:
#     day  company closing price
# 0   man   google          1129
# 1   tue   google          1132
# 2   wed   google          1134
# 3   thu   google          1152
# 4   fri   google          1152
# 5   man    apple           191
# 6   tue    apple           192
# 7   wed    apple           190
# 8   thu    apple           190
# 9   fri    apple           188
# 10  man  sumsung           191
# 11  tue  sumsung           192
# 12  wed  sumsung           190
# 13  thu  sumsung           190
# 14  fri  sumsung           188
