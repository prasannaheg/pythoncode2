# %%
import matplotlib.pyplot as plt
ages=[2,5,70,40,38,45,50,45,43,40,44,60,7,17,57,18,90,77,52,21,20,40]
range=(0,100)
bins=10
plt.hist(ages,bins,range,color='green',histtype='bar',width=5.5)
plt.xlabel('age')
plt.ylabel('no of people')
plt.title('my histogram')
plt.show()
